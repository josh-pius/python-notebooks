# %%
import os
import nltk
import csv
# os.chdir('C:/Users/USER/Downloads')

# %%
os.chdir('C:/Users/USER/Documents/DSB Assignments/Module 1')
smsdata=open('spam.csv','r')
csv_reader = csv.reader(smsdata,delimiter=',')
smsdata_labels=[]
smsdata_data=[]

for line in csv_reader:
    smsdata_labels.append(line[0])
    smsdata_data.append(line[1])
smsdata.close()

# %%
smsdata
# Out:
# <_io.TextIOWrapper name='spam.csv' mode='r' encoding='cp1252'>

# %%
for i in range(5):
    print(smsdata_labels[i],smsdata_data[i])
# Out:
# ham Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
# ham Ok lar... Joking wif u oni...
# spam Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's
# ham U dun say so early hor... U c already then say...
# ham Nah I don't think he goes to usf, he lives around here though

# %%
from collections import Counter
c = Counter (smsdata_labels)
print(c)
# Out:
# Counter({'ham': 4825, 'spam': 747})

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import string
import pandas as pd
from nltk import pos_tag
from nltk.stem import PorterStemmer
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
print(string.punctuation)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
def preprocessing(text):
    text2 = " ".join("".join([" " if ch in string.punctuation else ch for ch in text]).split())
    print(text2)
    tokens = [word for sent in nltk.sent_tokenize(text2) for word in nltk.word_tokenize(sent)]

    tokens = [word.lower() for word in tokens]

    stopwds = stopwords.words('english')
    tokens=[token for token in tokens if token not in stopwds]
    tokens=[word for word in tokens if len(word)>=3]
    stemmer = PorterStemmer()
    tokens = [stemmer.stem(word) for word in tokens]

    tagged_corpus = pos_tag(tokens)
    Noun_tags = ['NN','NNP','NNPS','NNS']
    Verb_tags = ['VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ']
    # print([(i,j) for i,j in zip(tokens,tagged_corpus)])
    lemmatizer = WordNetLemmatizer()

    def prat_lemmatizer(token,tag):
        if tag in Noun_tags:
            return lemmatizer.lemmatize(token,'n')
        elif tag in Verb_tags:
            return lemmatizer.lemmatize(token,'v')
        else:
            return lemmatizer.lemmatize(token,'n')
    pre_proc_text = " ".join([prat_lemmatizer(token,tag) for token,tag in tagged_corpus])
    return pre_proc_text

# %%
smsdata_data_2 = []
for i in smsdata_data:
    smsdata_data_2.append(preprocessing(i));
# Out:
# Go until jurong point crazy Available only in bugis n great world la e buffet Cine there got amore wat
# [('jurong', ('jurong', 'JJ')), ('point', ('point', 'NN')), ('crazi', ('crazi', 'NN')), ('avail', ('avail', 'NN')), ('bugi', ('bugi', 'NN')), ('great', ('great', 'JJ')), ('world', ('world', 'NN')), ('buffet', ('buffet', 'NN')), ('cine', ('cine', 'NN')), ('got', ('got', 'VBD')), ('amor', ('amor', 'JJ')), ('wat', ('wat', 'NN'))]
# Ok lar Joking wif u oni
# [('lar', ('lar', 'JJ')), ('joke', ('joke', 'NN')), ('wif', ('wif', 'NN')), ('oni', ('oni', 'NN'))]
# Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005 Text FA to 87121 to receive entry question std txt rate T C s apply 08452810075over18 s
# ...

# %%
smsdata_data_2
